# %% [markdown]
# Задание 44 В ячейке ниже представлен код генерирующий DataFrame, которая состоит всего из 1 столбца. Ваша задача перевести его в one hot вид. Сможете ли вы это сделать без get_dummies?

# %%
import random
import pandas as pd

lst = ['robot'] * 10
lst += ['human'] * 10
random.shuffle(lst)
data = pd.DataFrame({'whoAmI':lst})
data.head()
# Out:
#   whoAmI
# 0  robot
# 1  robot
# 2  human
# 3  human
# 4  robot

# %%
data.whoAmI.unique()
# Out:
# array(['robot', 'human'], dtype=object)

# %%
el = 'robot'

data.loc[data.whoAmI == el, el] = 1

data.head()
# Out:
#   whoAmI  robot
# 0  robot    1.0
# 1  robot    1.0
# 2  human    NaN
# 3  human    NaN
# 4  human    NaN

# %%
for el in data.whoAmI.unique():
  data.loc[data.whoAmI == el, el] = 1
  data.loc[data.whoAmI != el, el] = 0

# %%
data.head()
# Out:
#   whoAmI  robot  human
# 0  robot    1.0    0.0
# 1  robot    1.0    0.0
# 2  human    0.0    1.0
# 3  human    0.0    1.0
# 4  robot    1.0    0.0
